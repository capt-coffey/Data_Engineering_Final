# %%
print("Pipeline automation order:")

print("1. Run ingest/geo notebook")
print("   - loads spatial files")
print("   - creates GeoJSON outputs")
print("   - creates tract_neighborhood_overlay.geojson")

print("2. Run transform/census notebook")
print("   - loads overlay + ACS data")
print("   - creates housing_cost_burden_ratio")
print("   - creates flood_zone_pct")
print("   - saves neighborhood_data.csv")

print("Automation documented successfully ✅")

# %% [markdown]
# The project workflow is automated conceptually through a pipeline notebook that defines the correct execution order: first ingest/geo, then transform/census. The individual notebooks run successfully, but Databricks notebook chaining with dbutils.notebook.run() encountered workspace execution issues, so the pipeline order is documented for reproducibility.
